# %% [markdown]
# Implementing a feedforward neural network (FNN) as a first step

# %%
from d2c.descriptors import D2C, DataLoader
from d2c.descriptors.utils import return_mb
import numpy as np

from tqdm import tqdm

# %%
dataloader = DataLoader()
dataloader.from_pickle('../example/synthetic_data.pkl')
observations = dataloader.get_observations()
dags = dataloader.get_dags()

# %%
len(observations)
# Out:
# 7000

# %%
def pad_mb(before_padding_MB, size = 3):
    if before_padding_MB.shape[1] < size:
        padding = np.zeros((before_padding_MB.shape[0], size - before_padding_MB.shape[1]))
        before_padding_MB = np.hstack([before_padding_MB, padding])
    
    if before_padding_MB.shape[1] > size:
        before_padding_MB = before_padding_MB[:, :3]
    
    return before_padding_MB

# %%
def prepare_data_for_couple(observations, dag, source_name, target_name, is_causal):
    
    # Estimate Markov blankets
    MBca = return_mb(dag, source_name)
    MBef = return_mb(dag, target_name)
    
    padded_MBca = pad_mb(observations[MBca].values)
    padded_MBef = pad_mb(observations[MBef].values)

    # Gather features
    features = np.hstack([
        observations[source_name].values.reshape(-1,1) ,        # Observations of X
        observations[target_name].values.reshape(-1,1) ,        # Observations of Y
        padded_MBca,  # Observations of MB of X
        padded_MBef   # Observations of MB of Y
    ])
    
    # Create a dictionary for the sample
    sample = {
        'features': features,
        'is_causal': is_causal,
        'edge_source': source_name,
        'edge_dest': target_name
    }
    
    return sample

# %%
# from multiprocessing import Pool, cpu_count

# def process_dag(index):
#     current_dag = dags[index]
#     current_observations = observations[index]
#     local_samples = []
#     for edge in current_dag.edges:
#         s1 = prepare_data_for_couple(current_observations, current_dag, edge[0], edge[1], 1)
#         s2 = prepare_data_for_couple(current_observations, current_dag, edge[1], edge[0], 0)
#         local_samples.append(s1)
#         local_samples.append(s2)
#     return local_samples

# if __name__ == '__main__':
#     with Pool(cpu_count()) as pool:
#         results = pool.map(process_dag, range(len(dags)))
    
#     # Flatten the list of lists
#     samples = [item for sublist in results for item in sublist]
from tqdm import tqdm
samples = []

for index in tqdm(range(len(dags))):
    current_dag = dags[index]
    current_observations = observations[index]
    for edge in current_dag.edges:
        s1 = prepare_data_for_couple(current_observations, current_dag, edge[0], edge[1], 1)
        s2 = prepare_data_for_couple(current_observations, current_dag, edge[1], edge[0], 0)
        samples.append(s1)
        samples.append(s2)
# Out:
# 100%|██████████| 7000/7000 [00:26<00:00, 259.45it/s]

# %%
# pickle samples
import pickle
with open('samples.pkl', 'wb') as f:
    pickle.dump(samples, f)

# # Load samples
# with open('samples.pkl', 'rb') as f:
#     samples = pickle.load(f)

# %%
import torch
from torch.utils.data import Dataset

class CausalDataset(Dataset):
    def __init__(self, samples):
        self.features = np.array([sample['features'] for sample in samples])
        self.labels = np.array([sample['is_causal'] for sample in samples])
        self.features = torch.tensor(self.features, dtype=torch.float32)
        self.labels = torch.tensor(self.labels, dtype=torch.long)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
import torch.nn as nn

class CausalInferenceNN(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_classes=2):
        super(CausalInferenceNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.relu2 = nn.ReLU()
        self.output_layer = nn.Linear(hidden_dim // 2, num_classes)
    
    def forward(self, x):

        x = x.view(x.size(0), -1)
        
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.output_layer(x)
        return x

# %%
from torch.utils.data import DataLoader, random_split

dataset = CausalDataset(samples)

# %%
len(train_dataset), len(val_dataset)
# Out:
# (57619, 14405)

# %%
# Split dataset
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
dataset.features.shape
# Out:
# torch.Size([72024, 250, 8])

# %%
input_dim = dataset.features.shape[1]*dataset.features.shape[2]
model = CausalInferenceNN(input_dim)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    for features, labels in loader:
        features, labels = features.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    return total_loss / len(loader)

# %%
def validate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    with torch.no_grad():
        for features, labels in loader:
            features, labels = features.to(device), labels.to(device)
            outputs = model(features)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
    accuracy = correct / len(loader.dataset)
    return total_loss / len(loader), accuracy

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_epochs = 20

for epoch in range(num_epochs):
    train_loss = train(model, train_loader, criterion, optimizer, device)
    val_loss, val_accuracy = validate(model, val_loader, criterion, device)
    
    print(f'Epoch {epoch+1}/{num_epochs}')
    print(f'Train Loss: {train_loss:.4f}')
    print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1/20
# Train Loss: 1727232024836.2031
# Validation Loss: 1657676313013.0603, Validation Accuracy: 0.8177
# Epoch 2/20
# Train Loss: 552210291922.3967
# Validation Loss: 110159164826.4803, Validation Accuracy: 0.7915
# Epoch 3/20
# Train Loss: 1162573609672.7090
# Validation Loss: 2848870140371.1919, Validation Accuracy: 0.8128
# Epoch 4/20
# Train Loss: 843222765007.9503
# Validation Loss: 606193893982.1510, Validation Accuracy: 0.8078
# Epoch 5/20
# Train Loss: 196987102357.6695
# Validation Loss: 216572935557.6734, Validation Accuracy: 0.8119
# Epoch 6/20
# Train Loss: 257478005058.0508
# Validation Loss: 483694109393.2570, Validation Accuracy: 0.8108
# Epoch 7/20
# Train Loss: 133439017925.0666
# Validation Loss: 277878479259.3223, Validation Accuracy: 0.8131
# Epoch 8/20
# Train Loss: 78694357053.2335
# Validation Loss: 33309115956.4907, Validation Accuracy: 0.8085
# Epoch 9/20
# Train Loss: 3383004143.1971
# Validation Loss: 122329813586.6343, Validation Accuracy: 0.8154
# Epoch 10/20
# Train Loss: 34625329722.4618
# Validation Loss: 258517409721.5028, Validation Accuracy: 0.8117
# Epoch 11/20
# Train Loss: 17304915286.6553
# Validation Loss: 189715298979.4037, Validation Accuracy: 0.8234
# Epoch 12/20
# Train Loss: 8687569768.0976
# Validation Loss: 33084299176.2606, Validation Accuracy: 0.8156
# Epoch 13/20
# Train Loss: 4318813061.7775
# Validation Loss: 36597113798.1741, Validation Accuracy: 0.8225
# Epoch 14/20
# Train Loss: 812629062.8119
# Validation Loss: 45782933220.9121, Validation Accuracy: 0.8253
# Epoch 15/20
# Train Loss: 1848392987.0709
# Validation Loss: 70343330221.0903, Validation Accuracy: 0.8241
# Epoch 16/20
# Train Loss: 3327117234.4064
# Validation Loss: 75413571528.8989, Validation Accuracy: 0.8290
# Epoch 17/20
# Train Loss: 17475519827.5162
# Validation Loss: 66878467650.3417, Validation Accuracy: 0.8325
# Epoch 18/20
# Train Loss: 17377976776.6296
# Validation Loss: 173729243434.5394, Validation Accuracy: 0.8290
# Epoch 19/20
# Train Loss: 51351603859.8614
# Validation Loss: 85124677716.3132, Validation Accuracy: 0.8259
# Epoch 20/20
# Train Loss: 2878822512.2958
# Validation Loss: 76110182825.0939, Validation Accuracy: 0.8314

# %%
import torch.nn.functional as F

def test(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    all_predictions = []
    all_probabilities = []
    with torch.no_grad():
        for features, labels in loader:
            features, labels = features.to(device), labels.to(device)
            outputs = model(features)
            
            # Compute probabilities using softmax
            probabilities = F.softmax(outputs, dim=1)
            all_probabilities.extend(probabilities.cpu().numpy())
            
            # Get predicted labels
            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    print(f'Test Accuracy: {accuracy:.4f}')
    
    return all_predictions, all_probabilities

# %%
x = np.array(val_dataset)
unique, counts = np.unique(x, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[    0 36012]
#  [    1 36012]]

# %%
test_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
predictions, probabilities = test(model, test_loader, device)
# Out:
# Test Accuracy: 0.8314

# %%
probabilities
# Out:
# [array([-0.06711925, -0.07848471], dtype=float32),
#  array([ 8.2306795, -1.1443149], dtype=float32),
#  array([-8.81163 ,  7.511959], dtype=float32),
#  array([0.13241565, 0.7659145 ], dtype=float32),
#  array([-11407.085,  10077.365], dtype=float32),
#  array([-0.0317541 ,  0.15514383], dtype=float32),
#  array([32.69563   ,  0.44536906], dtype=float32),
#  array([1.2359437, 0.7110414], dtype=float32),
#  array([-0.32865036,  0.1479882 ], dtype=float32),
#  array([4.700784  , 0.04450328], dtype=float32),
#  array([ 8.542162  , -0.27089012], dtype=float32),
#  array([-16.10503  ,  13.8095455], dtype=float32),
#  array([-0.64252615,  1.067321  ], dtype=float32),
#  array([-282.8842 ,  236.61456], dtype=float32),
#  array([1.4413583 , 0.51307917], dtype=float32),
#  array([-5.5171847,  4.663129 ], dtype=float32),
#  array([-0.9254652 ,  0.78765225], dtype=float32),
#  array([-0.38893798,  0.20019427], dtype=float32),
#  array([8.749686  , 0.29989123], dtype=float32),
#  array([-1.9512722,  3.0460813], dtype=float32),
#  array([5.9951434 , 0.48782212], dtype=float32),
#  array([1.7830317 , 0.38449246], dtype=float32),
#  array([-0.633262  ,  0.41176668], dtype=float32),
#  array([-1.0650831 ,  0.81706935], dtype=float32),
#  array([-14.837356,  12.818654], dtype=float32),
#  array([-1.2191284,  2.3773804], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.38464355,  0.50929004], dtype=float32),
#  array([-0.5715646 ,  0.36852807], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.02831464, 0.43764657], dtype=float32),
#  array([0.04989146, 0.361855  ], dtype=float32),
#  array([1.7117587 , 0.50274885], dtype=float32),
#  array([-0.5865911 ,  0.39872056], dtype=float32),
#  array([16.373291,  1.539893], dtype=float32),
#  array([-0.13950098,  0.90590245], dtype=float32),
#  array([-2.6605742,  2.1774423], dtype=float32),
#  array([0.34298614, 0.34448594], dtype=float32),
#  array([1.2466891 , 0.20558226], dtype=float32),
#  array([-5.6251087,  5.8195453], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.51659083, 1.2566197 ], dtype=float32),
#  array([-0.16924393,  0.30503586], dtype=float32),
#  array([2.9530053 , 0.77817464], dtype=float32),
#  array([1.7772585, 0.6171332], dtype=float32),
#  array([-0.14751837,  0.03492328], dtype=float32),
#  array([-3.9239295,  3.317826 ], dtype=float32),
#  array([-1.5465589,  3.5682113], dtype=float32),
#  array([-2.121427 ,  1.7819561], dtype=float32),
#  array([18.89451   , -0.63979906], dtype=float32),
#  array([0.07872044, 6.8202896 ], dtype=float32),
#  array([0.07738554, 1.4263616 ], dtype=float32),
#  array([7.059935 , 1.1331334], dtype=float32),
#  array([-0.3958779,  0.6517099], dtype=float32),
#  array([-3.6100376,  4.92086  ], dtype=float32),
#  array([0.69787204, 0.65062207], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-7.9663625,  6.7965994], dtype=float32),
#  array([ 2.7120218 , -0.69693846], dtype=float32),
#  array([-0.08379889,  0.86698663], dtype=float32),
#  array([-3.1261075,  2.6122832], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([1.6280073 , 0.43170488], dtype=float32),
#  array([-2.1699362,  1.7551272], dtype=float32),
#  array([1.8883268, 0.5247745], dtype=float32),
#  array([1.3399878, 1.3276124], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-9.142773 ,  7.9394007], dtype=float32),
#  array([-3.8047888,  3.1942077], dtype=float32),
#  array([-3.5131185,  2.9503543], dtype=float32),
#  array([1.7360601 , 0.36739042], dtype=float32),
#  array([-0.57536155,  0.3922056 ], dtype=float32),
#  array([-4.9778514,  4.283969 ], dtype=float32),
#  array([-1.7506836e+09,  1.3505960e+09], dtype=float32),
#  array([2.0445137, 1.1181307], dtype=float32),
#  array([1.712455 , 0.6137697], dtype=float32),
#  array([867.0786 , -16.45405], dtype=float32),
#  array([3.196119  , 0.23640007], dtype=float32),
#  array([-0.9579312 ,  0.71672964], dtype=float32),
#  array([1.4602956 , 0.04153533], dtype=float32),
#  array([6.8789835, 1.1547502], dtype=float32),
#  array([-0.55900127,  0.9714071 ], dtype=float32),
#  array([-7.996037 ,  7.0129614], dtype=float32),
#  array([0.868116  , 0.03894205], dtype=float32),
#  array([-2.232989 ,  1.8580381], dtype=float32),
#  array([3.751456  , 0.61485964], dtype=float32),
#  array([4.285084  , 0.48883724], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([6.3413486, 1.3271652], dtype=float32),
#  array([2.8165607 , 0.08539767], dtype=float32),
#  array([-5433.31,  4618.11], dtype=float32),
#  array([0.99790144, 1.0961708 ], dtype=float32),
#  array([-1.0270903,  1.2974845], dtype=float32),
#  array([0.8918328 , 0.39637506], dtype=float32),
#  array([ 0.18928364, -0.14015973], dtype=float32),
#  array([0.989758  , 0.99972826], dtype=float32),
#  array([1.0580188, 0.3714108], dtype=float32),
#  array([-4.7480016,  3.9900682], dtype=float32),
#  array([1.0378643, 0.3656441], dtype=float32),
#  array([2.1596696 , 0.22457671], dtype=float32),
#  array([6.3931026, 1.0195638], dtype=float32),
#  array([2.6192439 , 0.34818703], dtype=float32),
#  array([-3.5270903,  2.933966 ], dtype=float32),
#  array([2.4355097 , 0.40723497], dtype=float32),
#  array([-1315.1345,  1146.463 ], dtype=float32),
#  array([17.79729  ,  1.4153572], dtype=float32),
#  array([-4.588898 ,  3.9151847], dtype=float32),
#  array([1.8307434 , 0.36531234], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([2.4633338e+13, 2.2150893e+12], dtype=float32),
#  array([3.3256912 , 0.74951094], dtype=float32),
#  array([3.4112492 , 0.08335299], dtype=float32),
#  array([ 2.721591  , -0.05350953], dtype=float32),
#  array([ 1.9152223 , -0.54585576], dtype=float32),
#  array([-0.8974513 ,  0.98410505], dtype=float32),
#  array([-0.5729817,  0.8721439], dtype=float32),
#  array([2.1791284, 0.8176161], dtype=float32),
#  array([-0.12870705,  1.6709384 ], dtype=float32),
#  array([2.6301348 , 0.16288209], dtype=float32),
#  array([-0.14605772,  0.9010919 ], dtype=float32),
#  array([-0.80942  ,  0.9267369], dtype=float32),
#  array([-63.067707,  53.41072 ], dtype=float32),
#  array([-1.7191907,  1.3585819], dtype=float32),
#  array([-1.3687920e+08,  1.2340069e+08], dtype=float32),
#  array([-5.778852e+11,  5.013871e+11], dtype=float32),
#  array([0.4237709, 1.9045595], dtype=float32),
#  array([-0.0389402,  1.037395 ], dtype=float32),
#  array([-3.6525455,  3.0263155], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-1.684657 ,  1.3500632], dtype=float32),
#  array([-20.816502,  18.50707 ], dtype=float32),
#  array([ 7.215072, -0.056441], dtype=float32),
#  array([-71.65428,  61.91243], dtype=float32),
#  array([-0.3271129,  1.1230308], dtype=float32),
#  array([-0.06217856, -0.07676587], dtype=float32),
#  array([2.8197873 , 0.40377256], dtype=float32),
#  array([-1.1745598e+17,  6.6366075e+16], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.6889407 , 0.18454385], dtype=float32),
#  array([1.9556144, 0.6842417], dtype=float32),
#  array([-55764.535,  46496.37 ], dtype=float32),
#  array([0.22962585, 0.2582066 ], dtype=float32),
#  array([-14.323488,  12.159284], dtype=float32),
#  array([3.1587865, 0.4981271], dtype=float32),
#  array([-0.20433241,  0.04033504], dtype=float32),
#  array([2.0575166 , 0.53642327], dtype=float32),
#  array([2.0683844, 3.5912082], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([19.878515 ,  2.5148308], dtype=float32),
#  array([-0.23172212,  1.2131478 ], dtype=float32),
#  array([ 1.2661021, -0.252805 ], dtype=float32),
#  array([1.866066  , 0.35396218], dtype=float32),
#  array([-0.38263124,  0.19473293], dtype=float32),
#  array([1.9833785 , 0.15748107], dtype=float32),
#  array([2.096798 , 0.3631735], dtype=float32),
#  array([-3.181698 ,  2.6355984], dtype=float32),
#  array([-0.2232    ,  0.05667344], dtype=float32),
#  array([0.14202511, 0.7260924 ], dtype=float32),
#  array([0.58172965, 1.1576442 ], dtype=float32),
#  array([0.28200102, 0.90570664], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([1.3860077, 2.8626907], dtype=float32),
#  array([-1.7353468,  1.7056375], dtype=float32),
#  array([-0.34947893,  0.12606597], dtype=float32),
#  array([-0.35892123,  0.68173313], dtype=float32),
#  array([1.0067956 , 0.23596168], dtype=float32),
#  array([0.48809242, 0.59421426], dtype=float32),
#  array([-0.28574014,  0.86566234], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.4713977 ,  0.27160028], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-155.85034,  127.42712], dtype=float32),
#  array([-0.8991866,  0.6420441], dtype=float32),
#  array([-0.8485545,  0.893377 ], dtype=float32),
#  array([0.6631843 , 0.17558336], dtype=float32),
#  array([-2.5504704,  2.1787484], dtype=float32),
#  array([-12569.725,  14776.879], dtype=float32),
#  array([-1.5587156,  1.2131634], dtype=float32),
#  array([1.6584412 , 0.48075658], dtype=float32),
#  array([-0.01224864,  0.86994237], dtype=float32),
#  array([1.353333  , 0.38390508], dtype=float32),
#  array([1.2456981 , 0.33801576], dtype=float32),
#  array([0.44496262, 0.5136472 ], dtype=float32),
#  array([-2.9325502,  2.422249 ], dtype=float32),
#  array([0.8620906 , 0.21469623], dtype=float32),
#  array([-17.082867,  14.67842 ], dtype=float32),
#  array([0.46644944, 0.49237907], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([ 3.971257 , -0.5325044], dtype=float32),
#  array([3.3111663, 0.5899614], dtype=float32),
#  array([0.68603337, 0.26035362], dtype=float32),
#  array([-3.2989085,  2.7861655], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-6.0269504,  6.703045 ], dtype=float32),
#  array([1430609.9 ,  497700.28], dtype=float32),
#  array([-1.6240538,  1.2804418], dtype=float32),
#  array([26338.031 ,   407.0194], dtype=float32),
#  array([3.8630626 , 0.16223913], dtype=float32),
#  array([-0.2210859 ,  0.68552226], dtype=float32),
#  array([0.09741395, 0.60345095], dtype=float32),
#  array([38.503326 , -1.0525061], dtype=float32),
#  array([4.1575003, 0.3061129], dtype=float32),
#  array([0.48299193, 0.20513758], dtype=float32),
#  array([0.02573108, 1.1257607 ], dtype=float32),
#  array([1.1737765, 0.7767233], dtype=float32),
#  array([1.5507109 , 0.17144307], dtype=float32),
#  array([2.925034, 0.284649], dtype=float32),
#  array([-0.4874856 ,  0.29766327], dtype=float32),
#  array([-3.9047372,  3.2651381], dtype=float32),
#  array([0.20853084, 0.6304481 ], dtype=float32),
#  array([ 5.965372  , -0.18596852], dtype=float32),
#  array([-0.78010654,  0.5749016 ], dtype=float32),
#  array([-291.0422 ,  241.94641], dtype=float32),
#  array([0.07856991, 0.03312326], dtype=float32),
#  array([1.409242 , 0.3201433], dtype=float32),
#  array([0.09168624, 0.81675243], dtype=float32),
#  array([1.8180828 , 0.35858387], dtype=float32),
#  array([1.3239628 , 0.10507006], dtype=float32),
#  array([1.8361157 , 0.09861077], dtype=float32),
#  array([-29.712458,  24.579668], dtype=float32),
#  array([2.0771065, 0.3711056], dtype=float32),
#  array([-0.7635196,  0.6279332], dtype=float32),
#  array([27876.174  ,  -151.23792], dtype=float32),
#  array([ 0.489933  , -0.05343201], dtype=float32),
#  array([-1.94466  ,  1.6246433], dtype=float32),
#  array([-258.55685,  216.55653], dtype=float32),
#  array([0.01317718, 0.3435222 ], dtype=float32),
#  array([13.02154  ,  0.5606095], dtype=float32),
#  array([1.2526159, 0.6242811], dtype=float32),
#  array([1.3352644 , 0.26894647], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([1.0220156 , 0.22586375], dtype=float32),
#  array([0.4494648 , 0.46096665], dtype=float32),
#  array([0.7137462 , 0.75653225], dtype=float32),
#  array([6.5553904, 0.9238363], dtype=float32),
#  array([ 1.8485578 , -0.51983535], dtype=float32),
#  array([-0.47003752,  0.30362028], dtype=float32),
#  array([-1.0483401e+10,  8.9379512e+09], dtype=float32),
#  array([1.0873476, 0.422476 ], dtype=float32),
#  array([1.9533132 , 0.23501241], dtype=float32),
#  array([0.06698992, 0.31487414], dtype=float32),
#  array([-0.48584473,  0.2841107 ], dtype=float32),
#  array([1.8577813 , 0.95566994], dtype=float32),
#  array([5.1020617 , 0.43624598], dtype=float32),
#  array([13.748467 ,  4.7278724], dtype=float32),
#  array([1.3473586 , 0.28708816], dtype=float32),
#  array([2.3659217e+15, 6.3676756e+14], dtype=float32),
#  array([-0.04589055,  0.40509215], dtype=float32),
#  array([4.0527577 , 0.06520654], dtype=float32),
#  array([41.208466, 14.281036], dtype=float32),
#  array([2.359297 , 0.2573508], dtype=float32),
#  array([-0.7226242 ,  0.79129034], dtype=float32),
#  array([-1965.4978,  1698.5675], dtype=float32),
#  array([1.2758375 , 0.16565898], dtype=float32),
#  array([ 9.456747 , -0.2754745], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([ 3.5064359 , -0.04910206], dtype=float32),
#  array([-12.868856,  10.495364], dtype=float32),
#  array([-0.18842417,  0.8476873 ], dtype=float32),
#  array([1.0922685, 0.4939738], dtype=float32),
#  array([-74850.48 ,  60897.023], dtype=float32),
#  array([6.2888627 , 0.32860595], dtype=float32),
#  array([-2.426432 ,  2.2154706], dtype=float32),
#  array([0.5056037 , 0.00512791], dtype=float32),
#  array([1.3162271 , 0.35210556], dtype=float32),
#  array([-0.41630316,  1.122951  ], dtype=float32),
#  array([-9341.581 ,  7982.8438], dtype=float32),
#  array([1.5753986 , 0.70987475], dtype=float32),
#  array([-0.5472102,  0.9335708], dtype=float32),
#  array([-3.8245687,  3.301676 ], dtype=float32),
#  array([3.4120433, 0.4798382], dtype=float32),
#  array([0.9262564 , 0.94251615], dtype=float32),
#  array([-33.498028,  27.96353 ], dtype=float32),
#  array([-13659.843,  11452.367], dtype=float32),
#  array([-0.6804429 ,  0.48982984], dtype=float32),
#  array([-0.12074364,  0.9515212 ], dtype=float32),
#  array([-0.5443138,  0.8653746], dtype=float32),
#  array([1.6828192 , 0.45345008], dtype=float32),
#  array([0.09358888, 0.26137954], dtype=float32),
#  array([-0.37673414,  1.1112726 ], dtype=float32),
#  array([0.77087015, 0.44415122], dtype=float32),
#  array([-0.29981434,  0.9334888 ], dtype=float32),
#  array([11.629422  , -0.33480173], dtype=float32),
#  array([-10.5374565,   9.215535 ], dtype=float32),
#  array([1.9387697, 0.4262882], dtype=float32),
#  array([-2.0288124,  1.6202438], dtype=float32),
#  array([0.05786812, 0.7785438 ], dtype=float32),
#  array([-0.3344313 ,  0.15337789], dtype=float32),
#  array([-0.17070162,  0.6989407 ], dtype=float32),
#  array([-13.267375,  11.286279], dtype=float32),
#  array([2.1085792 , 0.48221725], dtype=float32),
#  array([241.43484 ,   4.543914], dtype=float32),
#  array([-0.6271549,  1.1418741], dtype=float32),
#  array([-0.393825  ,  0.81817555], dtype=float32),
#  array([140.44115  ,   0.7103651], dtype=float32),
#  array([-0.00707019,  0.8629233 ], dtype=float32),
#  array([3.3211148 , 0.43234485], dtype=float32),
#  array([1.3161582 , 0.69231415], dtype=float32),
#  array([-19.878021,  17.903173], dtype=float32),
#  array([24.445183,  8.449194], dtype=float32),
#  array([2.3245544 , 0.48897165], dtype=float32),
#  array([ 1.9565171 , -0.49290675], dtype=float32),
#  array([1.1421964, 0.817809 ], dtype=float32),
#  array([0.5672938 , 0.04469422], dtype=float32),
#  array([-7.808752,  6.795697], dtype=float32),
#  array([0.09096216, 0.5195189 ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-6.5268239e+09,  5.7099264e+09], dtype=float32),
#  array([1.4708992 , 0.34765252], dtype=float32),
#  array([-18.787262,  16.572947], dtype=float32),
#  array([1.2965873 , 0.07341401], dtype=float32),
#  array([0.49385035, 0.11667313], dtype=float32),
#  array([1.5774835 , 0.23951006], dtype=float32),
#  array([-0.45009512,  0.2531533 ], dtype=float32),
#  array([0.42348093, 0.5930824 ], dtype=float32),
#  array([-0.34399903,  1.4609356 ], dtype=float32),
#  array([3.0415106, 0.6660893], dtype=float32),
#  array([-0.8184158,  0.6285038], dtype=float32),
#  array([-126.06837,  112.36843], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([1.4973259 , 0.59106755], dtype=float32),
#  array([-0.6864577,  0.4578315], dtype=float32),
#  array([-0.9186219,  1.038679 ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.13855231, 0.76184934], dtype=float32),
#  array([-0.50893104,  0.30410224], dtype=float32),
#  array([4.7300057 , 0.10492951], dtype=float32),
#  array([1.3661581 , 0.66252667], dtype=float32),
#  array([-1.6962773,  1.3322849], dtype=float32),
#  array([-0.58164036,  0.512438  ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-3.1135175,  2.559544 ], dtype=float32),
#  array([19.335087  ,  0.12253196], dtype=float32),
#  array([-1574.3103,  1391.8798], dtype=float32),
#  array([0.01212614, 1.0833278 ], dtype=float32),
#  array([23.588808  ,  0.21761805], dtype=float32),
#  array([-107.009186,   93.548195], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-3.7737575,  5.1642046], dtype=float32),
#  array([9317.22   ,  -19.74151], dtype=float32),
#  array([-1.1289676,  0.9174591], dtype=float32),
#  array([-191.43832,  165.63942], dtype=float32),
#  array([2.016803  , 0.45195478], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([2.527462  , 0.01411564], dtype=float32),
#  array([-4.5572004,  3.833063 ], dtype=float32),
#  array([-0.12885028,  0.9203375 ], dtype=float32),
#  array([0.18255764, 0.33741516], dtype=float32),
#  array([5.844122 , 0.7573685], dtype=float32),
#  array([-2.5419738,  4.207659 ], dtype=float32),
#  array([0.31936693, 0.8979594 ], dtype=float32),
#  array([1.714178  , 0.05789805], dtype=float32),
#  array([-0.098442  ,  0.25805393], dtype=float32),
#  array([1.5746086 , 0.43758833], dtype=float32),
#  array([0.2257427 , 0.66851324], dtype=float32),
#  array([0.25392625, 0.00270142], dtype=float32),
#  array([1.9213365, 0.1536969], dtype=float32),
#  array([ 3.9758441 , -0.02984225], dtype=float32),
#  array([3.0092027, 0.1583628], dtype=float32),
#  array([1.4222442, 1.1280724], dtype=float32),
#  array([1.3465819, 0.9419711], dtype=float32),
#  array([-1.3159698,  1.0235841], dtype=float32),
#  array([-2.108821,  1.69711 ], dtype=float32),
#  array([3.586386 , 0.8303996], dtype=float32),
#  array([-0.8351715,  0.5885477], dtype=float32),
#  array([ 4.7048054 , -0.07896762], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-1.0623296 ,  0.78477037], dtype=float32),
#  array([1.2894694 , 0.38122293], dtype=float32),
#  array([0.8279958 , 0.23292026], dtype=float32),
#  array([-0.34930396,  1.8315839 ], dtype=float32),
#  array([5.4332223, 1.4142588], dtype=float32),
#  array([1.9571992 , 0.17307973], dtype=float32),
#  array([-0.58694434,  1.7506473 ], dtype=float32),
#  array([ 0.05241799, -0.03689844], dtype=float32),
#  array([-9.028054, 13.17269 ], dtype=float32),
#  array([-0.61682856,  0.39753616], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-1.5556678,  1.284613 ], dtype=float32),
#  array([-0.68407047,  0.46442187], dtype=float32),
#  array([-0.9699455,  0.8060421], dtype=float32),
#  array([-0.22946316,  0.1316553 ], dtype=float32),
#  array([1.5226992, 0.5374964], dtype=float32),
#  array([-0.6043683,  2.4361699], dtype=float32),
#  array([ 1.2587041, -0.0442129], dtype=float32),
#  array([7.566598  , 0.27152747], dtype=float32),
#  array([-0.67886895,  1.2110468 ], dtype=float32),
#  array([1.3252366 , 0.29043552], dtype=float32),
#  array([1.8400747 , 0.37260643], dtype=float32),
#  array([0.9826914 , 0.41840896], dtype=float32),
#  array([ 3.887752  , -0.02174615], dtype=float32),
#  array([-1.8278526,  1.7703177], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.34163716,  0.15923414], dtype=float32),
#  array([-3.209089 ,  5.9155526], dtype=float32),
#  array([-197.08629,  169.08951], dtype=float32),
#  array([0.7085949, 0.4730205], dtype=float32),
#  array([ 4.63462   , -0.05834209], dtype=float32),
#  array([5.063605 , 1.1221176], dtype=float32),
#  array([4.0058994 , 0.09230358], dtype=float32),
#  array([0.75431776, 0.00334672], dtype=float32),
#  array([1.2418439 , 0.26636076], dtype=float32),
#  array([-1.7456085e+12,  1.5807572e+12], dtype=float32),
#  array([0.47280133, 0.8017965 ], dtype=float32),
#  array([-18619.39 ,  15225.977], dtype=float32),
#  array([-0.09025281, -0.0584522 ], dtype=float32),
#  array([19.000128 ,  0.9622627], dtype=float32),
#  array([-0.4691118,  0.2696208], dtype=float32),
#  array([1.4232762, 0.4458307], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.26351866, 0.43716234], dtype=float32),
#  array([1.8674686 , 0.23908442], dtype=float32),
#  array([8.1574564e+09, 5.7226797e+08], dtype=float32),
#  array([0.98671114, 0.5232529 ], dtype=float32),
#  array([2.8791835 , 0.92007244], dtype=float32),
#  array([ 6.0456743 , -0.23974818], dtype=float32),
#  array([-2.8988733,  2.373673 ], dtype=float32),
#  array([1.9230889 , 0.30274606], dtype=float32),
#  array([32.93055 ,  3.637182], dtype=float32),
#  array([1.9859203, 0.3145503], dtype=float32),
#  array([-0.82164234,  0.5863554 ], dtype=float32),
#  array([0.4362167 , 0.02745309], dtype=float32),
#  array([6.4043465 , 0.36340624], dtype=float32),
#  array([-0.40277347,  0.5289173 ], dtype=float32),
#  array([84.493614 ,  0.7990673], dtype=float32),
#  array([0.34651494, 0.34000134], dtype=float32),
#  array([15.796642 ,  0.6344574], dtype=float32),
#  array([-0.74586487,  0.53277725], dtype=float32),
#  array([0.6697601, 3.2025874], dtype=float32),
#  array([-3.6940120e+13,  3.1988302e+13], dtype=float32),
#  array([-21.122223,  17.828737], dtype=float32),
#  array([1.9978925, 0.6340821], dtype=float32),
#  array([-1.6517807,  1.4132022], dtype=float32),
#  array([1.9306883 , 0.44999903], dtype=float32),
#  array([-0.9799974,  0.7671158], dtype=float32),
#  array([-243.40952,  207.51944], dtype=float32),
#  array([-0.0616144 ,  0.48175836], dtype=float32),
#  array([0.5565885 , 0.51411843], dtype=float32),
#  array([-2.0754342,  1.6694752], dtype=float32),
#  array([-0.59490263,  1.212027  ], dtype=float32),
#  array([0.09949382, 0.30209374], dtype=float32),
#  array([ 6.94708974e+15, -1.09887416e+15], dtype=float32),
#  array([-0.73034406,  0.24814427], dtype=float32),
#  array([0.13937438, 0.7355601 ], dtype=float32),
#  array([-0.2305175 ,  0.31830412], dtype=float32),
#  array([-11330.712,   9843.145], dtype=float32),
#  array([-2.581432 ,  2.1101344], dtype=float32),
#  array([-0.7552811,  1.0098267], dtype=float32),
#  array([-5.8751583,  4.8431544], dtype=float32),
#  array([560.85004  ,   1.9588269], dtype=float32),
#  array([-1.8189372,  1.4385023], dtype=float32),
#  array([-0.4929065,  0.6131885], dtype=float32),
#  array([1032.8958  ,    5.047118], dtype=float32),
#  array([-58952.434,  48201.055], dtype=float32),
#  array([105.4006   ,  -1.3073388], dtype=float32),
#  array([1.87926  , 0.5019522], dtype=float32),
#  array([-1.4492968,  4.3580313], dtype=float32),
#  array([-2.1057048,  1.6942607], dtype=float32),
#  array([3.2343829 , 0.08218259], dtype=float32),
#  array([0.31427777, 0.8645292 ], dtype=float32),
#  array([0.17974448, 0.83196145], dtype=float32),
#  array([1.6822784, 0.2552821], dtype=float32),
#  array([-0.15295926,  0.4380526 ], dtype=float32),
#  array([0.73282635, 0.12071573], dtype=float32),
#  array([3723564.5 ,  277001.47], dtype=float32),
#  array([0.45107365, 1.3104314 ], dtype=float32),
#  array([0.5833244 , 0.44330132], dtype=float32),
#  array([5.3279963 , 0.11347563], dtype=float32),
#  array([1.1823562 , 0.22504038], dtype=float32),
#  array([-3.5585608,  3.1102045], dtype=float32),
#  array([-1.2817342,  1.0522559], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.9503373 ,  0.70845914], dtype=float32),
#  array([2.215027 , 0.3541908], dtype=float32),
#  array([2.322368  , 0.09752847], dtype=float32),
#  array([-10.489526,   8.784247], dtype=float32),
#  array([-4.937958 ,  4.2276125], dtype=float32),
#  array([ 9.35784  , -0.4280048], dtype=float32),
#  array([0.31777322, 3.8250923 ], dtype=float32),
#  array([-2.443931,  1.979716], dtype=float32),
#  array([0.33048403, 0.48593873], dtype=float32),
#  array([6.6144805 , 0.05366666], dtype=float32),
#  array([-2.051733 ,  1.6960182], dtype=float32),
#  array([0.1095795 , 0.19956172], dtype=float32),
#  array([-0.5847565,  1.108808 ], dtype=float32),
#  array([0.17807746, 0.7472869 ], dtype=float32),
#  array([-0.42368746,  0.8563775 ], dtype=float32),
#  array([ 3.1091168 , -0.09414213], dtype=float32),
#  array([1.3897071 , 0.59144557], dtype=float32),
#  array([1.3559772 , 0.33698034], dtype=float32),
#  array([92758.27   ,  -234.64539], dtype=float32),
#  array([30.761194,  2.756449], dtype=float32),
#  array([-3.1269126,  2.5830634], dtype=float32),
#  array([-0.05257595,  1.1428952 ], dtype=float32),
#  array([1.049898  , 0.19932699], dtype=float32),
#  array([0.18768638, 0.28965402], dtype=float32),
#  array([7327.6084  ,   32.729378], dtype=float32),
#  array([ 6.623838  , -0.12546134], dtype=float32),
#  array([0.41277683, 0.20156312], dtype=float32),
#  array([0.76258236, 0.38370165], dtype=float32),
#  array([-561898.6 ,  471673.47], dtype=float32),
#  array([-5.8867917,  4.8298984], dtype=float32),
#  array([ 0.11773316, -0.0141757 ], dtype=float32),
#  array([0.51693165, 0.13328964], dtype=float32),
#  array([23357.145  ,   503.73987], dtype=float32),
#  array([-941.2396 ,  814.92993], dtype=float32),
#  array([0.63583165, 0.6848951 ], dtype=float32),
#  array([-4.7560635,  5.5368185], dtype=float32),
#  array([2.6771185 , 0.18057948], dtype=float32),
#  array([1.0353141 , 0.34914306], dtype=float32),
#  array([-1.7645876,  1.3914382], dtype=float32),
#  array([-2.7383854,  3.159568 ], dtype=float32),
#  array([1.5173686 , 0.05742637], dtype=float32),
#  array([-1.2727104,  1.0622596], dtype=float32),
#  array([-0.8014154,  0.5573791], dtype=float32),
#  array([-1.0107709 ,  0.80108684], dtype=float32),
#  array([-1.5073166,  1.213918 ], dtype=float32),
#  array([1.835527 , 0.3460236], dtype=float32),
#  array([1.1038821 , 0.35459274], dtype=float32),
#  array([1.0245684 , 0.30643392], dtype=float32),
#  array([4.7525206 , 0.25367194], dtype=float32),
#  array([-50.23256,  41.72046], dtype=float32),
#  array([1.7987154 , 0.33287537], dtype=float32),
#  array([-2.7599103,  2.2328758], dtype=float32),
#  array([3.1200745 , 0.37481987], dtype=float32),
#  array([2.3034358, 0.5856405], dtype=float32),
#  array([1.4524298 , 0.50437605], dtype=float32),
#  array([0.2795453, 1.1792239], dtype=float32),
#  array([-0.40819418,  0.3551113 ], dtype=float32),
#  array([-6.5153704,  5.6313896], dtype=float32),
#  array([28.852844 , -1.3706156], dtype=float32),
#  array([-1.7017797,  1.5742805], dtype=float32),
#  array([-2.8725464,  2.482136 ], dtype=float32),
#  array([-0.1739803,  0.6167892], dtype=float32),
#  array([-0.79497343,  0.8918699 ], dtype=float32),
#  array([-1.7607158,  3.3988974], dtype=float32),
#  array([0.5509754, 0.4504707], dtype=float32),
#  array([3.925295  , 0.05191315], dtype=float32),
#  array([1.8035146, 0.2836966], dtype=float32),
#  array([1.7952152, 0.5118424], dtype=float32),
#  array([0.81664705, 0.16471198], dtype=float32),
#  array([-0.2442314 ,  0.30994684], dtype=float32),
#  array([868.10956 ,   7.728896], dtype=float32),
#  array([0.5858711 , 0.40395504], dtype=float32),
#  array([8.110638, 1.374006], dtype=float32),
#  array([0.41426003, 0.69390666], dtype=float32),
#  array([ 4.0622993 , -0.38537067], dtype=float32),
#  array([-0.04906198, -0.14730401], dtype=float32),
#  array([22.669209,  1.507347], dtype=float32),
#  array([ 2.545532 , -0.2720785], dtype=float32),
#  array([68.29844  ,  1.1297663], dtype=float32),
#  array([-4.2596965,  3.5749843], dtype=float32),
#  array([4.920978 , 0.1481215], dtype=float32),
#  array([0.97338474, 0.11191425], dtype=float32),
#  array([0.54702306, 0.13517159], dtype=float32),
#  array([5.3808966, 0.3050397], dtype=float32),
#  array([-28.879627,  24.034792], dtype=float32),
#  array([-1.4757342,  1.1544776], dtype=float32),
#  array([-149.08769,  123.67298], dtype=float32),
#  array([0.360542  , 0.47740072], dtype=float32),
#  array([1.4428434, 0.3603624], dtype=float32),
#  array([-3.5396984,  2.9401681], dtype=float32),
#  array([0.22321963, 0.9821928 ], dtype=float32),
#  array([0.77925724, 0.19979054], dtype=float32),
#  array([-1.9943871,  1.7747935], dtype=float32),
#  array([-2.571884 ,  2.1622024], dtype=float32),
#  array([-15183.934,  13278.779], dtype=float32),
#  array([-1.310646  ,  0.99834746], dtype=float32),
#  array([-2.8027337,  2.302591 ], dtype=float32),
#  array([-0.39967012,  0.20948777], dtype=float32),
#  array([8.403788  , 0.20304784], dtype=float32),
#  array([2.187373  , 0.32363766], dtype=float32),
#  array([-0.5150495,  0.8675365], dtype=float32),
#  array([-1.2110063,  6.8056107], dtype=float32),
#  array([1.4501493, 0.3382132], dtype=float32),
#  array([8.980068 , 1.7578632], dtype=float32),
#  array([2.9082115 , 0.74926776], dtype=float32),
#  array([-0.22226915,  0.05586737], dtype=float32),
#  array([ 1.8410586 , -0.04754745], dtype=float32),
#  array([-0.1591846,  0.3414095], dtype=float32),
#  array([-12.713888,  10.916095], dtype=float32),
#  array([-4.7773027,  4.3121376], dtype=float32),
#  array([-2.5021286,  4.35905  ], dtype=float32),
#  array([-9.628291 ,  8.1956415], dtype=float32),
#  array([1.4485381 , 0.35377017], dtype=float32),
#  array([2.096189  , 0.13309157], dtype=float32),
#  array([1.528358 , 0.2827647], dtype=float32),
#  array([-0.8867984 ,  0.63131654], dtype=float32),
#  array([-1.0804229,  0.8967505], dtype=float32),
#  array([0.09467744, 1.2619117 ], dtype=float32),
#  array([3.8331587, 0.6001659], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([ 0.1714096, -0.0327007], dtype=float32),
#  array([1.7874618 , 0.17645085], dtype=float32),
#  array([-0.8357835,  0.8420722], dtype=float32),
#  array([-1.193624 ,  0.9365749], dtype=float32),
#  array([ 1.0484203, -0.5518106], dtype=float32),
#  array([1.0863259, 0.5541492], dtype=float32),
#  array([3.3860986 , 0.30660993], dtype=float32),
#  array([4.770532 , 1.0594932], dtype=float32),
#  array([1.2169688 , 0.17603081], dtype=float32),
#  array([78329.23  ,  6964.6045], dtype=float32),
#  array([0.71418065, 0.5932718 ], dtype=float32),
#  array([-0.8136095,  4.215391 ], dtype=float32),
#  array([-10.753344,   9.527259], dtype=float32),
#  array([-9.761759 ,  8.4590225], dtype=float32),
#  array([-0.9094928 ,  0.75884473], dtype=float32),
#  array([-0.5376702,  0.3307181], dtype=float32),
#  array([-5.454219,  4.617283], dtype=float32),
#  array([-1.5118934e+12,  1.2217127e+12], dtype=float32),
#  array([-3.4810522,  2.8958664], dtype=float32),
#  array([-0.12603939,  0.37392533], dtype=float32),
#  array([-2.1584525,  1.7325056], dtype=float32),
#  array([0.07506662, 0.46877605], dtype=float32),
#  array([0.2430923, 1.4774204], dtype=float32),
#  array([-37018.703,  32529.273], dtype=float32),
#  array([2.7439203 , 0.22036201], dtype=float32),
#  array([-2.1461976,  3.2835488], dtype=float32),
#  array([0.4863932 , 0.24642259], dtype=float32),
#  array([-5.696675 ,  9.5708685], dtype=float32),
#  array([ 9.234711  , -0.11100429], dtype=float32),
#  array([-0.35831764,  0.25300014], dtype=float32),
#  array([-0.6822346 ,  0.49858534], dtype=float32),
#  array([-1.9679387,  1.5751756], dtype=float32),
#  array([0.57074404, 1.3240534 ], dtype=float32),
#  array([-0.6957615 ,  0.55143046], dtype=float32),
#  array([3.6884148 , 0.04325391], dtype=float32),
#  array([-0.65583724,  0.46511376], dtype=float32),
#  array([-1.115242 ,  1.3649763], dtype=float32),
#  array([-0.63358533,  0.5055415 ], dtype=float32),
#  array([-0.66673076,  0.87452275], dtype=float32),
#  array([-0.71364295,  0.73611665], dtype=float32),
#  array([0.540229  , 0.35398108], dtype=float32),
#  array([4.059676  , 0.28077134], dtype=float32),
#  array([5.2579694 , 0.06647474], dtype=float32),
#  array([0.91512734, 0.3340348 ], dtype=float32),
#  array([3.2560046 , 0.29803044], dtype=float32),
#  array([0.26233727, 0.27204853], dtype=float32),
#  array([-20.97523,  17.60309], dtype=float32),
#  array([-1.9029642,  1.5180813], dtype=float32),
#  array([-1.1217418 ,  0.99057287], dtype=float32),
#  array([-3.0698524,  4.1646414], dtype=float32),
#  array([9.987226 , 1.3591285], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-2.1657012,  1.7387826], dtype=float32),
#  array([0.84376144, 0.21872789], dtype=float32),
#  array([4.9706116, 0.5636211], dtype=float32),
#  array([0.6722572, 0.5495837], dtype=float32),
#  array([4.275286  , 0.11926491], dtype=float32),
#  array([0.3108216 , 0.61067265], dtype=float32),
#  array([ 1.5772821 , -0.00217658], dtype=float32),
#  array([0.05253028, 0.7579142 ], dtype=float32),
#  array([7.282816 , 1.8341609], dtype=float32),
#  array([-1.110045  ,  0.96786946], dtype=float32),
#  array([1.2102948 , 0.48578143], dtype=float32),
#  array([34.802   ,  4.232544], dtype=float32),
#  array([27.004946 ,  1.6966462], dtype=float32),
#  array([-0.29619712,  0.5850976 ], dtype=float32),
#  array([3.547159  , 0.15312523], dtype=float32),
#  array([0.21001542, 1.2104785 ], dtype=float32),
#  array([-2.2991781,  1.9876949], dtype=float32),
#  array([2.4643328, 0.4304406], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-10.127369,   8.412511], dtype=float32),
#  array([2.6074257 , 0.69156736], dtype=float32),
#  array([-1.0069454 ,  0.75842345], dtype=float32),
#  array([5.6989284 , 0.07313664], dtype=float32),
#  array([-1.1622998 ,  0.96781737], dtype=float32),
#  array([0.55369806, 0.77197427], dtype=float32),
#  array([-0.14020687,  0.785883  ], dtype=float32),
#  array([21.114763 ,  1.1944038], dtype=float32),
#  array([3.857846  , 0.04963867], dtype=float32),
#  array([2.7031844, 0.733802 ], dtype=float32),
#  array([-9.523611,  8.110365], dtype=float32),
#  array([1.9587544 , 0.39045435], dtype=float32),
#  array([1.6696731 , 0.15239021], dtype=float32),
#  array([2.522182e+11, 8.774515e+10], dtype=float32),
#  array([-0.35463178,  0.30195844], dtype=float32),
#  array([0.51662755, 1.74972   ], dtype=float32),
#  array([-46.209953,  40.983498], dtype=float32),
#  array([-0.3680439 ,  0.87735194], dtype=float32),
#  array([-151.6635 ,  133.91704], dtype=float32),
#  array([-1.2850814,  0.9762098], dtype=float32),
#  array([-1.1751525,  0.8850066], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-6.1526666,  5.514852 ], dtype=float32),
#  array([-2.9122052,  2.403649 ], dtype=float32),
#  array([ 1.0225296 , -0.11514648], dtype=float32),
#  array([8.186229 , 0.7831096], dtype=float32),
#  array([0.66300017, 0.9789024 ], dtype=float32),
#  array([0.5613571 , 0.40650415], dtype=float32),
#  array([-1.4191095,  1.107642 ], dtype=float32),
#  array([-4.0187306,  4.134503 ], dtype=float32),
#  array([ 4.637917 , -0.3349476], dtype=float32),
#  array([-2.919113 ,  2.4704273], dtype=float32),
#  array([0.42977232, 0.47305542], dtype=float32),
#  array([-4.1211295,  3.456271 ], dtype=float32),
#  array([-40.312588,  34.27471 ], dtype=float32),
#  array([2.7914007 , 0.12967837], dtype=float32),
#  array([163760.72 ,   7871.311], dtype=float32),
#  array([-0.20638227,  0.55093956], dtype=float32),
#  array([-22.240992,  19.470945], dtype=float32),
#  array([0.49192005, 0.73043865], dtype=float32),
#  array([-0.40035406,  0.21008   ], dtype=float32),
#  array([-17.798225,  14.708055], dtype=float32),
#  array([-0.806247  ,  0.67860067], dtype=float32),
#  array([212.57896   ,   0.37502176], dtype=float32),
#  array([-0.34762162,  0.17698923], dtype=float32),
#  array([-318.72275,  281.83527], dtype=float32),
#  array([-1.9319733,  1.5363859], dtype=float32),
#  array([0.40940952, 0.16744113], dtype=float32),
#  array([2.285591  , 0.13088876], dtype=float32),
#  array([2.0129168, 0.9989225], dtype=float32),
#  array([1.2239205 , 0.21929735], dtype=float32),
#  array([-4.1457334,  4.158497 ], dtype=float32),
#  array([-1.2722722,  0.9686412], dtype=float32),
#  array([1.0278442 , 0.68717986], dtype=float32),
#  array([ 1.1381932 , -0.02814072], dtype=float32),
#  array([-39.52382 ,  33.595734], dtype=float32),
#  array([-0.5832456 ,  0.55231386], dtype=float32),
#  array([8.107991 , 1.8071609], dtype=float32),
#  array([-0.3987488,  0.2197471], dtype=float32),
#  array([-3.1888978,  2.6529295], dtype=float32),
#  array([-1.2556626,  0.9542685], dtype=float32),
#  array([-0.15702102,  0.18240413], dtype=float32),
#  array([0.55589855, 0.4821421 ], dtype=float32),
#  array([2.0842514, 0.5887899], dtype=float32),
#  array([1.1714253, 0.3523973], dtype=float32),
#  array([0.15423644, 3.4926    ], dtype=float32),
#  array([-4395.195 ,  3656.9617], dtype=float32),
#  array([0.20142293, 0.10787221], dtype=float32),
#  array([3.7796953 , 0.44684947], dtype=float32),
#  array([3.8107927 , 0.73011345], dtype=float32),
#  array([47.7207   , -0.8071739], dtype=float32),
#  array([11.772413  ,  0.92739433], dtype=float32),
#  array([-0.4229902,  1.1043906], dtype=float32),
#  array([-2.7585678,  3.5238597], dtype=float32),
#  array([-0.32105684,  0.28586277], dtype=float32),
#  array([0.41262448, 0.60371906], dtype=float32),
#  array([-4.0596595,  3.3788557], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([20.119856 ,  1.0257791], dtype=float32),
#  array([0.8067143, 1.2323126], dtype=float32),
#  array([1.515181 , 0.2220318], dtype=float32),
#  array([-0.55799115,  1.651013  ], dtype=float32),
#  array([0.87604356, 0.39888316], dtype=float32),
#  array([-5.5559335,  4.6957965], dtype=float32),
#  array([-0.88278115,  0.98384506], dtype=float32),
#  array([10.276579 ,  1.6682338], dtype=float32),
#  array([0.2328074 , 0.59922284], dtype=float32),
#  array([-3.7073553,  3.2480352], dtype=float32),
#  array([-0.20326161,  1.0804487 ], dtype=float32),
#  array([-1.0104874,  0.8292209], dtype=float32),
#  array([3.1707847, 0.4873796], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.638983,  2.792068], dtype=float32),
#  array([-0.3349742 ,  0.15411377], dtype=float32),
#  array([ 1.0626504, -0.259871 ], dtype=float32),
#  array([-1.188734,  1.123924], dtype=float32),
#  array([1.6160254, 0.4675712], dtype=float32),
#  array([9.319607 , 0.9284988], dtype=float32),
#  array([-2.2803226,  1.8858765], dtype=float32),
#  array([-2.9416965e+09,  2.5473626e+09], dtype=float32),
#  array([-14.525601,  12.244879], dtype=float32),
#  array([-0.65496933,  0.48148352], dtype=float32),
#  array([11.399409  ,  0.76168114], dtype=float32),
#  array([1.506147 , 0.4754644], dtype=float32),
#  array([19.323624  ,  0.19718987], dtype=float32),
#  array([ 1.1201972 , -0.11550351], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.21251944,  0.04742461], dtype=float32),
#  array([-1.5753033,  1.3207465], dtype=float32),
#  array([2.658549  , 0.16453171], dtype=float32),
#  array([-0.70768887,  0.4787932 ], dtype=float32),
#  array([5.078145 , 0.3592369], dtype=float32),
#  array([1.5645071, 0.1650661], dtype=float32),
#  array([-2.215227 ,  1.9087762], dtype=float32),
#  array([1.3525227, 0.4245376], dtype=float32),
#  array([-1.6752257,  1.3140553], dtype=float32),
#  array([-0.33646786,  1.4120616 ], dtype=float32),
#  array([-0.37291977,  0.18632329], dtype=float32),
#  array([-1.2565408 ,  0.95558625], dtype=float32),
#  array([-11.149283,   9.531484], dtype=float32),
#  array([0.17954308, 0.2391591 ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-1473.0879,  1183.4459], dtype=float32),
#  array([2.1283238 , 0.46145684], dtype=float32),
#  array([0.24525073, 0.12982196], dtype=float32),
#  array([1.175903  , 0.14761594], dtype=float32),
#  array([8.899304  , 0.62216765], dtype=float32),
#  array([ 1.8077255, -0.2568134], dtype=float32),
#  array([0.41229373, 1.3245424 ], dtype=float32),
#  array([187.88638 ,  -2.208938], dtype=float32),
#  array([2.2010398 , 0.49697334], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([1.1221595, 0.9658013], dtype=float32),
#  array([-1.226707 ,  1.0507038], dtype=float32),
#  array([0.5928819 , 0.11535358], dtype=float32),
#  array([ 8.883689, -0.500901], dtype=float32),
#  array([21.553635 ,  1.2421263], dtype=float32),
#  array([-27.9152  ,  24.036562], dtype=float32),
#  array([-0.361179  ,  0.47281176], dtype=float32),
#  array([-6.716173 ,  5.7394114], dtype=float32),
#  array([8355.792  , -376.53967], dtype=float32),
#  array([1.0328455 , 0.30063438], dtype=float32),
#  array([0.64252406, 0.33983868], dtype=float32),
#  array([1.1383846 , 0.34090263], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([112.62045  ,   5.9634523], dtype=float32),
#  array([-4.253638 ,  3.4637973], dtype=float32),
#  array([-4.930761,  6.586388], dtype=float32),
#  array([1.8772801, 0.4883651], dtype=float32),
#  array([30.982243 ,  1.6694139], dtype=float32),
#  array([2.3883548 , 0.51537955], dtype=float32),
#  array([1.1831578 , 0.64631206], dtype=float32),
#  array([1.3361742 , 0.25086492], dtype=float32),
#  array([-0.0129329,  0.8380669], dtype=float32),
#  array([9.893100e+12, 1.317759e+12], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-1.9580586,  1.6561022], dtype=float32),
#  array([2.1259763 , 0.01550315], dtype=float32),
#  array([-2.1623716,  1.8629755], dtype=float32),
#  array([-10.915288,  11.067992], dtype=float32),
#  array([0.15181372, 0.3489862 ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-4.84135  ,  4.0841856], dtype=float32),
#  array([58.22871  ,  1.1346768], dtype=float32),
#  array([13.228685,  4.180597], dtype=float32),
#  array([6.043554 , 1.0788672], dtype=float32),
#  array([-0.3902111 ,  0.92344147], dtype=float32),
#  array([-0.47939533,  0.66481644], dtype=float32),
#  array([-3.7083673,  3.1350782], dtype=float32),
#  array([ 3.4732301, -0.4515913], dtype=float32),
#  array([ 4.873488 , -0.5551483], dtype=float32),
#  array([1.8263297, 0.5699971], dtype=float32),
#  array([-0.99064314, 14.080362  ], dtype=float32),
#  array([13.655688  , -0.31314355], dtype=float32),
#  array([-0.9378737,  0.7004642], dtype=float32),
#  array([0.8790995, 0.6845259], dtype=float32),
#  array([-0.7960737,  0.5527535], dtype=float32),
#  array([0.48738563, 0.93084246], dtype=float32),
#  array([-0.8165587,  0.6059218], dtype=float32),
#  array([-7.0226645,  6.870907 ], dtype=float32),
#  array([-17.519724,  15.424721], dtype=float32),
#  array([1.7742969 , 0.38416594], dtype=float32),
#  array([-11.580154,   9.89123 ], dtype=float32),
#  array([-0.4344983 ,  0.68056893], dtype=float32),
#  array([-0.9508927 ,  0.72975695], dtype=float32),
#  array([124.929085,  43.40692 ], dtype=float32),
#  array([37.885166 , -0.9112231], dtype=float32),
#  array([-1.4734838,  3.9014966], dtype=float32),
#  array([ 7.936438  , -0.13008732], dtype=float32),
#  array([0.07419562, 0.46501786], dtype=float32),
#  array([0.36905187, 0.1545831 ], dtype=float32),
#  array([2.4687696 , 0.07499398], dtype=float32),
#  array([0.19796765, 0.8257616 ], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.15132034, 0.84081167], dtype=float32),
#  array([-1.0206537,  1.1838518], dtype=float32),
#  array([-7.960862,  8.770883], dtype=float32),
#  array([ 1.2623998 , -0.01458731], dtype=float32),
#  array([27.48945 ,  5.418178], dtype=float32),
#  array([-1.1517782 ,  0.86489767], dtype=float32),
#  array([1.3972086 , 0.19265091], dtype=float32),
#  array([-0.31485376,  0.13604102], dtype=float32),
#  array([-1.5411669,  1.4110683], dtype=float32),
#  array([2.902546 , 0.9032255], dtype=float32),
#  array([0.2267802 , 0.33130348], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([0.40377575, 0.7942013 ], dtype=float32),
#  array([-0.49215716, -1.1747667 ], dtype=float32),
#  array([41.356735 , -2.4773448], dtype=float32),
#  array([-2163.8206,  1890.517 ], dtype=float32),
#  array([-1.930139 ,  1.5384722], dtype=float32),
#  array([1.0244493 , 0.23869354], dtype=float32),
#  array([33.21906  ,  3.1147697], dtype=float32),
#  array([42.007565 ,  1.4752382], dtype=float32),
#  array([0.88791114, 0.40004098], dtype=float32),
#  array([-0.79490536,  0.65627915], dtype=float32),
#  array([-0.11642379,  0.6502616 ], dtype=float32),
#  array([-3.7546908e+11,  4.0673031e+11], dtype=float32),
#  array([4.966899  , 0.35296845], dtype=float32),
#  array([2.5984015 , 0.08427054], dtype=float32),
#  array([1.1176475 , 0.19955823], dtype=float32),
#  array([34.561768  , -0.29033083], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.47076806,  0.2720483 ], dtype=float32),
#  array([0.3217758, 0.7510346], dtype=float32),
#  array([-3.7116473e+10,  3.2141015e+10], dtype=float32),
#  array([40.445515 , -0.6319024], dtype=float32),
#  array([-9132.403,  7672.552], dtype=float32),
#  array([-5.126246,  4.463229], dtype=float32),
#  array([3.6937165 , 0.20166665], dtype=float32),
#  array([-0.108297,  0.942439], dtype=float32),
#  array([3.366886 , 0.4563399], dtype=float32),
#  array([-0.53584015,  1.1458602 ], dtype=float32),
#  array([1.3891726 , 0.56672907], dtype=float32),
#  array([0.26149487, 1.0295047 ], dtype=float32),
#  array([1.2479249e+10, 1.6940159e+09], dtype=float32),
#  array([-0.37552977,  1.3616073 ], dtype=float32),
#  array([-1.5955837,  1.2450893], dtype=float32),
#  array([8.909043 , 1.3861914], dtype=float32),
#  array([-0.2832489,  1.053734 ], dtype=float32),
#  array([-26.868595,  23.88326 ], dtype=float32),
#  array([1.420975 , 0.5574372], dtype=float32),
#  array([1.8805557, 0.3592078], dtype=float32),
#  array([10.334434  ,  0.68771714], dtype=float32),
#  array([55.83984  , -0.6289479], dtype=float32),
#  array([-1.4107887,  7.5039225], dtype=float32),
#  array([29.79941  ,  2.4468439], dtype=float32),
#  array([-0.4282026,  0.7567677], dtype=float32),
#  array([0.29212558, 0.6916405 ], dtype=float32),
#  array([-0.24982655,  0.36999637], dtype=float32),
#  array([85.2529  , 29.603819], dtype=float32),
#  array([-0.14127834, -0.01426663], dtype=float32),
#  array([0.53899324, 0.37498066], dtype=float32),
#  array([-8.88803  ,  7.7008862], dtype=float32),
#  array([-0.5552226,  0.499577 ], dtype=float32),
#  array([-0.44406953,  0.27552572], dtype=float32),
#  array([-12.876846,  11.181111], dtype=float32),
#  array([1.5603939 , 0.18986875], dtype=float32),
#  array([-705.1652 ,  587.55396], dtype=float32),
#  array([11.570096 ,  0.2777804], dtype=float32),
#  array([1.6366853 , 0.10552008], dtype=float32),
#  array([1.7458265 , 0.43268692], dtype=float32),
#  array([2.826391  , 0.38681293], dtype=float32),
#  array([7.231485 , 1.5184268], dtype=float32),
#  array([-2.484904 ,  2.0151963], dtype=float32),
#  array([-1.2323798,  2.1993997], dtype=float32),
#  array([-1.4683515,  1.2932154], dtype=float32),
#  array([78.61195  , -2.3475387], dtype=float32),
#  array([-0.7340323,  0.5272726], dtype=float32),
#  array([-1.0464196 ,  0.76954055], dtype=float32),
#  array([22.103884,  2.038267], dtype=float32),
#  array([0.5417634, 0.2396166], dtype=float32),
#  array([0.2438519, 0.6108038], dtype=float32),
#  array([-1.2814549,  0.9790769], dtype=float32),
#  array([22.428648 , -0.7604286], dtype=float32),
#  array([-29.083385,  25.048153], dtype=float32),
#  array([0.5948513, 0.4448642], dtype=float32),
#  array([0.47354066, 0.45568275], dtype=float32),
#  array([0.8927716 , 0.57381433], dtype=float32),
#  array([ 2.1319642, -0.2654151], dtype=float32),
#  array([0.4359972 , 0.31501994], dtype=float32),
#  array([0.24289286, 4.2610316 ], dtype=float32),
#  array([1.0606722 , 0.23456526], dtype=float32),
#  array([-28.625103,  24.610992], dtype=float32),
#  array([-5.106664 ,  4.4313602], dtype=float32),
#  array([-1.0434861,  0.8362502], dtype=float32),
#  array([6.0281987, 0.7473096], dtype=float32),
#  array([2.561152  , 0.22093117], dtype=float32),
#  array([0.36235482, 0.45453852], dtype=float32),
#  array([2.0472918 , 0.12014932], dtype=float32),
#  array([4.236023  , 0.59725326], dtype=float32),
#  array([39.583168  ,  0.66161186], dtype=float32),
#  array([0.44425702, 0.6108553 ], dtype=float32),
#  array([0.44258475, 0.64288414], dtype=float32),
#  array([-0.7664439 ,  0.56807417], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([-0.938745 ,  2.1086001], dtype=float32),
#  array([-0.48457497,  1.1126789 ], dtype=float32),
#  array([1.2922076, 0.5111472], dtype=float32),
#  array([7.1922364, 1.0466294], dtype=float32),
#  array([1.418031, 1.05255 ], dtype=float32),
#  array([-0.0136316 ,  0.15806082], dtype=float32),
#  array([ 7.1067166 , -0.10983836], dtype=float32),
#  array([-2.4118593,  1.9657971], dtype=float32),
#  array([0.4888839 , 0.20901677], dtype=float32),
#  array([2.558913  , 0.20571578], dtype=float32),
#  array([1.7226294 , 0.36657143], dtype=float32),
#  array([-15.454865,  12.881825], dtype=float32),
#  array([ 2.30218   , -0.01469695], dtype=float32),
#  array([-1.1058255,  0.8209832], dtype=float32),
#  array([-4.665637,  5.436497], dtype=float32),
#  array([-0.06711925, -0.07848471], dtype=float32),
#  array([2.5926952 , 0.30797243], dtype=float32),
#  array([-0.991658 ,  1.0049925], dtype=float32),
#  array([-3.1105597,  2.5700343], dtype=float32),
#  array([1.0839624 , 0.19478166], dtype=float32),
#  array([17.20908  ,  1.6596478], dtype=float32),
#  array([-0.08786239,  0.12220449], dtype=float32),
#  array([-4.812074 ,  4.5143733], dtype=float32),
#  array([53.79431  ,  0.5892046], dtype=float32),
#  array([2.2417881, 0.502254 ], dtype=float32),
#  array([23.932505 ,  2.0701714], dtype=float32),
#  array([9.074463  , 0.02940328], dtype=float32),
#  array([-2.885167 ,  2.3742743], dtype=float32),
#  array([0.61712795, 1.0384966 ], dtype=float32),
#  array([4.6987233 , 0.43407142], dtype=float32),
#  array([-0.6824266 ,  0.45434076], dtype=float32),
#  array([1.8033913 , 0.60539293], dtype=float32),
#  array([2.667146  , 0.01311163], dtype=float32),
#  array([5.533611  , 0.45326972], dtype=float32),
#  array([-2.9631968,  2.5541797], dtype=float32),
#  array([-0.35933954,  1.1801643 ], dtype=float32),
#  array([5.745441, 0.358446], dtype=float32),
#  array([ 5.4017215 , -0.12164795], dtype=float32),
#  ...]

# %%
x = np.array(predictions)
unique, counts = np.unique(x, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[   0 7535]
#  [   1 6870]]

# %%
val_labels = []

# Iterate over the validation loader
for batch in val_loader:
    _, labels = batch  # Since your __getitem__ method in CausalDataset returns features, labels
    val_labels.append(labels)

# Concatenate all validation labels into a single tensor
val_labels = torch.cat(val_labels, dim=0)


y_true = val_labels.numpy()
y_hat = np.array(predictions)

from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

confusion = confusion_matrix(y_true, y_hat)

f1 = f1_score(y_true, y_hat)

precision = precision_score(y_true, y_hat)

recall = recall_score(y_true, y_hat)

print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print('Confusion Matrix:')
print(confusion)
# Out:
# F1 Score: 0.8274
# Precision: 0.8473
# Recall: 0.8084
# Confusion Matrix:
# [[6155 1049]
#  [1380 5821]]
