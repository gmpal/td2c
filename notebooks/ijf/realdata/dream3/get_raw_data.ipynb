# %%
! pip install --upgrade synapseclient
# Out:
# ...
#   Using cached synapseclient-4.6.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.0.0
#     Uninstalling psutil-6.0.0:
#       Successfully uninstalled psutil-6.0.0
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import synapseclient 
import synapseutils 

syn = synapseclient.Synapse() 
syn.login(authToken="eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..GAErZzjOljjt5b91Bavl4XDiN-OPTC3-dWHY5dDaFceD5yNU1fE_lIQXUvAPgguIf-0BaX9SU-OMXgNG3PPFEtoSvjHaXi1Wv-oEsz1UDYWvgPEognHEWKwC1S7R_158F8p7HzLM94sd0R3ys2RlbUsvlXmgOpi4bCtZa_VvA-QmsKlfLyf60Th19Q8DQL1hfM0kL3gYzI5zp0TgR91LdgUom4-eyeOQ7hiTuUxtF9XcNCn22bpqb9KI3z3mQBNHiGNtCYz6mS-tB3rXSWf1-Bnthhg0eDSpwAUnyQCNoimWyxSayMbcyHkQNyoegv8AQHbodA_0mp61pEgTNKL9dw") 
files = synapseutils.syncFromSynapse(syn, 'syn2853594', path='.')
# Out:
# Welcome, gmpal!
# ...
# Syncing Project (syn2853594:DREAM3 - In Silico Network Challenge) from Synapse.
# ...
# Syncing Folder (syn2853596:sub challenge 1) from Synapse.
# ...
# Syncing Folder (syn2853605:gold standard) from Synapse.
# ...
# Syncing Folder (syn2853598:test data) from Synapse.
# ...
# Syncing Folder (syn2853600:publication data) from Synapse.
# ...
# Syncing Folder (syn2853599:scoring methodology) from Synapse.
# ...
# Copying existing file from /home/gpaldino/.synapseCache/948/793948/DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt to /home/gpaldino/td2c/src/dream3/sub challenge 1/gold standard/DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt
# ...
# Syncing Folder (syn2853597:training data) from Synapse.
# ...
# Copying existing file from /home/gpaldino/.synapseCache/944/793944/DREAM3GoldStandard_InSilicoSize100_Yeast1.txt to /home/gpaldino/td2c/src/dream3/sub challenge 1/gold standard/DREAM3GoldStandard_InSilicoSize100_Yeast1.txt
# ...

# %%
files
# Out:
# [File(cacheDir='/home/gpaldino/.synapseCache/948/793948', concreteType='org.sagebionetworks.repo.model.FileEntity', createdOn='2014-11-19T10:35:50.082Z', id='syn2853610', createdBy='375805', modifiedBy='375805', versionLabel='1', name='DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt', isLatestVersion=True, modifiedOn='2014-11-19T10:35:50.082Z', files=['DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt'], path='/home/gpaldino/.synapseCache/948/793948/DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt', etag='5b450dfa-7ab2-11e9-98fa-026b0a0ad230', parentId='syn2853605', _file_handle={'id': '793948', 'etag': '5eabba94-9495-4a01-bda3-9680609fd6b5', 'createdBy': '375805', 'createdOn': '2014-11-19T10:35:49.000Z', 'modifiedOn': '2014-11-19T10:35:49.000Z', 'concreteType': 'org.sagebionetworks.repo.model.file.S3FileHandle', 'contentType': 'text/plain', 'contentMd5': 'a023c71cb880a470bfb236a8628431af', 'fileName': 'DREAM3GoldStandard_InSilicoSize100_Ecoli1.txt', 'storageLocationId': 1, 'contentSize': 107
# ...

# %%
import numpy as np

# Load the file (assuming it's a tab-separated matrix)
file_path = files[2].path
with open(file_path, 'r') as f:
    lines = f.readlines()

lines
# Out:
# ['G1\tG2\t1\n',
#  'G2\tG3\t1\n',
#  'G4\tG3\t1\n',
#  'G2\tG4\t1\n',
#  'G2\tG5\t1\n',
#  'G7\tG5\t1\n',
#  'G9\tG5\t1\n',
#  'G5\tG6\t1\n',
#  'G51\tG7\t1\n',
#  'G5\tG8\t1\n',
#  'G7\tG8\t1\n',
#  'G9\tG8\t1\n',
#  'G20\tG9\t1\n',
#  'G8\tG10\t1\n',
#  'G9\tG10\t1\n',
#  'G18\tG10\t1\n',
#  'G8\tG11\t1\n',
#  'G9\tG11\t1\n',
#  'G8\tG12\t1\n',
#  'G10\tG12\t1\n',
#  'G6\tG13\t1\n',
#  'G7\tG14\t1\n',
#  'G14\tG15\t1\n',
#  'G14\tG16\t1\n',
#  'G15\tG16\t1\n',
#  'G33\tG16\t1\n',
#  'G7\tG17\t1\n',
#  'G9\tG19\t1\n',
#  'G20\tG21\t1\n',
#  'G20\tG22\t1\n',
#  'G20\tG23\t1\n',
#  'G20\tG24\t1\n',
#  'G24\tG25\t1\n',
#  'G29\tG25\t1\n',
#  'G34\tG25\t1\n',
#  'G25\tG26\t1\n',
#  'G25\tG27\t1\n',
#  'G38\tG27\t1\n',
#  'G25\tG28\t1\n',
#  'G29\tG30\t1\n',
#  'G41\tG30\t1\n',
#  'G25\tG31\t1\n',
#  'G25\tG32\t1\n',
#  'G38\tG32\t1\n',
#  'G48\tG33\t1\n',
#  'G53\tG33\t1\n',
#  'G79\tG33\t1\n',
#  'G35\tG34\t1\n',
#  'G37\tG34\t1\n',
#  'G40\tG34\t1\n',
#  'G37\tG35\t1\n',
# ...
